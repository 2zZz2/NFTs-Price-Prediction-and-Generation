# %%
# !pip install --upgrade pip
# !pip install pandas
# !pip install requests
# !pip install datetime
# !pip install gql

# %%
import pandas as pd

# %%
df = pd.read_csv ('Data_API.csv')
# Out:
# /Users/zhouchang/miniconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3012: DtypeWarning: Columns (0,1,2,4,6,8,9,10,14,15,20) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df.columns
# Out:
# Index(['Smart_contract', 'ID_token', 'Transaction_hash', 'Seller_address',
#        'Seller_username', 'Buyer_address', 'Buyer_username', 'Image_url_1',
#        'Image_url_2', 'Image_url_3', 'Image_url_4', 'Price_Crypto', 'Crypto',
#        'Price_USD', 'Name', 'Description', 'Collection', 'Market',
#        'Datetime_updated', 'Datetime_updated_seconds', 'Permanent_link',
#        'Unique_id_collection', 'Collection_cleaned', 'Category'],
#       dtype='object')

# %%
df.head()["Crypto"]
# Out:
# 0    ETH
# 1    ETH
# 2    ETH
# 3    ETH
# 4    ETH
# Name: Crypto, dtype: object

# %%
df["Category"].unique()
# Out:
# array(['Games', 'Art', 'Other', 'Collectible', 'Metaverse', 'Utility'],
#       dtype=object)

# %%
df2 = pd.read_csv ('NFT_sales.csv',  nrows=1000)

# %%
df2
# Out:
#            Date  Sales_USD_cumsum  Number_of_Sales_cumsum  \
# 0    2017-06-22      0.000000e+00                       0
# 1    2017-06-23      1.020300e+03                      19
# 2    2017-06-24      2.261140e+03                      40
# 3    2017-06-25      2.778690e+03                      53
# 4    2017-06-26      3.203320e+03                      67
# ..          ...               ...                     ...
# 995  2020-03-12      1.027627e+08                 4312418
# 996  2020-03-13      1.028115e+08                 4314612
# 997  2020-03-14      1.028480e+08                 4319882
# 998  2020-03-15      1.028904e+08                 4325906
# 999  2020-03-16      1.029287e+08                 4331753
#
#      Active_Market_Wallets_cumsum  Primary_Sales_cumsum  \
# 0                             0.0                     0
# 1                             8.0                     0
# 2                            21.0                     0
# ...

# %%
df1 = pd.read_csv ('Cleaning_collections.csv')

# %%
df1
# Out:
#             Key
# 0    Aavegotchi
# 1      Abstract
# 2        Absurd
# 3          Adam
# 4     Adventure
# ..          ...
# 294       World
# 295         Wow
# 296     Wrapped
# 297      Zodiac
# 298      Zombie
#
# [299 rows x 1 columns]
